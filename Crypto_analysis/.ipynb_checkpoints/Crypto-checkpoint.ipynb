# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web
from scipy.stats import linregress
import pylab
import mplfinance as mpf
import seaborn as sn

# %%
web.get_data_yahoo("DOT1-USD",
start = "2020-02-01",
end = "2021-01-17")
# Out:
#                  High        Low       Open      Close        Volume  \
# Date
# 2020-08-19   3.077784   2.692896   2.787857   2.900080  4.881987e+07
# 2020-08-20   3.090093   2.730919   2.896923   2.875028  4.931314e+07
# 2020-08-21   4.510613   2.816762   2.878570   4.484690  4.858011e+08
# 2020-08-22   4.487058   3.716271   4.487058   3.967066  3.207495e+08
# 2020-08-23   4.783158   3.812670   3.987413   4.602614  4.076902e+08
# ...               ...        ...        ...        ...           ...
# 2021-01-13  11.299746   7.989519   8.265112  10.957710  2.915711e+09
# 2021-01-14  14.549704  10.925012  10.947876  14.539050  5.405055e+09
# 2021-01-15  14.855377  11.851579  14.522520  13.212381  6.159631e+09
# 2021-01-16  19.322062  13.185755  13.198050  18.180424  8.917082e+09
# 2021-01-17  18.116222  16.522512  17.291542  16.981972  8.643613e+09
#
#             Adj Close
# Date
# 2020-08-19   2.900080
# 2020-08-20   2.875028
# 2020-08-21   4.484690
# 2020-08-22   3.967066
# 2020-08-23   4.602614
# ...               ...
# 2021-01-13  10.957710
# 2021-01-14  14.539050
# 2021-01-15  13.212381
# 2021-01-16  18.180424
# 2021-01-17  16.981972
#
# [131 rows x 6 columns]

# %%
tickers = ["BTC-USD", "ETH-USD", "DOT1-USD", "XRP-USD", "ADA-USD", "LTC-USD"]
multpl_crypto = web.get_data_yahoo(tickers,
start = "2020-04-01",
end = "2021-01-08")

# %%
multpl_crypto
# Out:
# Attributes     Adj Close                                              \
# Symbols          BTC-USD      ETH-USD   DOT1-USD   XRP-USD   ADA-USD
# Date
# 2020-03-31   6606.776367   135.634552        NaN  0.175323  0.030855
# 2020-04-01   6793.624512   142.029144        NaN  0.178640  0.031984
# 2020-04-02   6733.387207   142.091309        NaN  0.179467  0.032295
# 2020-04-03   6867.527344   145.219391        NaN  0.181732  0.032505
# 2020-04-04   6791.129395   143.546646        NaN  0.179406  0.032003
# ...                  ...          ...        ...       ...       ...
# 2021-01-05  33992.429688  1100.006104   9.701655  0.226750  0.258314
# 2021-01-06  36824.363281  1207.112183  10.096068  0.250895  0.331898
# 2021-01-07  39371.042969  1225.678101   9.644586  0.326002  0.299980
# 2021-01-08  40797.609375  1224.197144   9.307136  0.323230  0.305597
# 2021-01-09  40254.546875  1281.077271   9.777765  0.326916  0.332973
#
# Attributes                     Close                                    ...  \
# Symbols        LTC-USD       BTC-USD      ETH-USD   DOT1-USD   XRP-USD  ...
# Date                                                                    ...
# 2020-03-31   39.380814   6606.776367   135.634552        NaN  0.175323  ...
# 2020-04-01   39.874168   6793.624512   142.029144        NaN  0.178640  ...
# 2020-04-02   40.359135   6733.387207   142.091309        NaN  0.179467  ...


# %%
fig = plt.figure()
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)

ax1.plot(multpl_crypto['Adj Close']['BTC-USD'])
ax1.set_title("BTC-USD")
ax2.plot(multpl_crypto['Adj Close']['ETH-USD'])
ax2.set_title("ETH-USD")
ax3.plot(multpl_crypto['Adj Close']['DOT1-USD'])
ax3.set_title("DOT1-USD")
ax4.plot(multpl_crypto['Adj Close']['XRP-USD'])
ax4.set_title("XRP-USD")
ax5.plot(multpl_crypto['Adj Close']['ADA-USD'])
ax5.set_title("ADA-USD")
ax6.plot(multpl_crypto['Adj Close']['LTC-USD'])
ax6.set_title("LTC-USD")

plt.tight_layout()
plt.show()

# %%
multpl_stock_daily_returns = multpl_crypto['Adj Close'].pct_change()
multpl_stock_monthly_returns = multpl_crypto['Adj Close'].resample('M').ffill().pct_change()

# %%
fig = plt.figure()
(multpl_stock_monthly_returns + 1).cumprod().plot()
plt.show()

# %%
mean_df = pd.DataFrame(multpl_stock_monthly_returns.mean())
mean_df
# Out:
#                  0
# Symbols
# BTC-USD   0.216314
# ETH-USD   0.293489
# DOT1-USD  0.143913
# XRP-USD   0.210940
# ADA-USD   0.326331
# LTC-USD   0.194254

# %%
mean_df.plot.barh()
plt.title('Average Return')
plt.xlabel('Return/month (x100)')
plt.legend('')

# %%
Std_df = pd.DataFrame(multpl_stock_monthly_returns.std())
Std_df
# Out:
#                  0
# Symbols
# BTC-USD   0.214538
# ETH-USD   0.335048
# DOT1-USD  0.389931
# XRP-USD   0.658996
# ADA-USD   0.403839
# LTC-USD   0.280409

# %%
Std_df.plot.barh()
plt.title('Volatility')
plt.xlabel('Standard Deviation')
plt.legend('')

# %%
corr_df = (multpl_stock_monthly_returns.corr())
corr_df
# Out:
# Symbols    BTC-USD   ETH-USD  DOT1-USD   XRP-USD   ADA-USD   LTC-USD
# Symbols
# BTC-USD   1.000000  0.722904  0.813279  0.358966  0.566781  0.915659
# ETH-USD   0.722904  1.000000  0.375278  0.644339  0.804402  0.835527
# DOT1-USD  0.813279  0.375278  1.000000 -0.067410  0.234313  0.730017
# XRP-USD   0.358966  0.644339 -0.067410  1.000000  0.683289  0.576007
# ADA-USD   0.566781  0.804402  0.234313  0.683289  1.000000  0.615818
# LTC-USD   0.915659  0.835527  0.730017  0.576007  0.615818  1.000000

# %%
corrMatrix = corr_df.corr()
sn.heatmap(corrMatrix, 
           annot=True,
           vmin=-1, vmax=1, center=0,
           cmap=sn.diverging_palette(20, 220, n=200),
           square=True
          )
plt.show()

# %%
tickers = ["ADA-USD", "ETH-USD", "DOT1-USD"]
multpl_stocks_top_3 = web.get_data_yahoo(tickers,
start = "2020-04-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = multpl_stocks_top_3['Adj Close'].pct_change()
multpl_stock_monthly_returns2 = multpl_stocks_top_3['Adj Close'].resample('M').ffill().pct_change()

# %%
fig = plt.figure()
(multpl_stock_daily_returns2 + 1).cumprod().plot()

plt.show()

# %%
tickers = ["DOT1-USD"]
DOT1_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = DOT1_stock['Adj Close']
multpl_stock_monthly_returns2 = DOT1_stock['Adj Close'].resample('M').ffill()

clean_DOT1 = multpl_stock_monthly_returns2.dropna()
print(clean_DOT1)
#multpl_stock_monthly_returns2
# Out:
# Symbols      DOT1-USD
# Date
# 2020-08-31   6.288766
# 2020-09-30   4.346024
# 2020-10-31   4.181767
# 2020-11-30   5.376430
# 2020-12-31   9.292508
# 2021-01-31  16.981972

# %%
x = [i for i in np.arange(1,7,1)]
y = clean_DOT1['DOT1-USD']

fig = plt.scatter(x, y)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.show()

# %%
multpl_stock_daily_returns2 = DOT1_stock['Adj Close']
multpl_stock_monthly_returns2 = DOT1_stock['Adj Close'].resample('M').ffill()

DOT1_stock2 = multpl_stock_daily_returns2.dropna()
DOT1_stock2
# Out:
# Symbols      DOT1-USD
# Date
# 2020-08-31   6.288766
# 2020-09-01   6.139465
# 2020-09-02   5.747868
# 2020-09-03   5.146038
# 2020-09-21   4.174463
# ...               ...
# 2021-01-13  10.957710
# 2021-01-14  14.539050
# 2021-01-15  13.212381
# 2021-01-16  18.180424
# 2021-01-17  16.981972
#
# [119 rows x 1 columns]

# %%
x = [i for i in np.arange(1,120,1)]
y = DOT1_stock2['DOT1-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('DOT1 Crypto')

plt.show()

# %%
tickers = ["ETH-USD"]
ETH_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = ETH_stock['Adj Close']
multpl_stock_monthly_returns2 = ETH_stock['Adj Close'].resample('M').ffill()

clean_ETH = multpl_stock_daily_returns2.dropna()
clean_ETH
# Out:
# Symbols         ETH-USD
# Date
# 2020-08-31   477.051910
# 2020-09-01   440.040497
# 2020-09-02   385.671936
# 2020-09-03   388.241150
# 2020-09-04   335.260071
# ...                 ...
# 2021-01-13  1130.739380
# 2021-01-14  1218.453003
# 2021-01-15  1171.834595
# 2021-01-16  1233.537598
# 2021-01-17  1232.425293
#
# [136 rows x 1 columns]

# %%
x = [i for i in np.arange(1,137,1)]
y = clean_ETH['ETH-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('ETH Crypto')

plt.show()

# %%
tickers = ["ADA-USD"]
ADA_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = ADA_stock['Adj Close']
multpl_stock_monthly_returns2 = ADA_stock['Adj Close']

clean_ADA = multpl_stock_daily_returns2.dropna()
clean_ADA
# Out:
# Symbols      ADA-USD
# Date
# 2020-08-31  0.125411
# 2020-09-01  0.115613
# 2020-09-02  0.096154
# 2020-09-03  0.102445
# 2020-09-04  0.089923
# ...              ...
# 2021-01-13  0.313609
# 2021-01-14  0.310396
# 2021-01-15  0.302530
# 2021-01-16  0.352444
# 2021-01-17  0.379843
#
# [136 rows x 1 columns]

# %%
x = [i for i in np.arange(1,137,1)]
y = clean_ADA['ADA-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('ADA Crypto')

plt.show()

# %%
tickers = ["BTC-USD"]
BTC_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = BTC_stock['Adj Close']
multpl_stock_monthly_returns2 = BTC_stock['Adj Close']

clean_BTC = multpl_stock_daily_returns2.dropna()
clean_BTC
# Out:
# Symbols          BTC-USD
# Date
# 2020-08-31  11970.478516
# 2020-09-01  11414.034180
# 2020-09-02  10245.296875
# 2020-09-03  10511.813477
# 2020-09-04  10169.567383
# ...                  ...
# 2021-01-13  37316.359375
# 2021-01-14  39187.328125
# 2021-01-15  36825.367188
# 2021-01-16  36178.140625
# 2021-01-17  35821.734375
#
# [136 rows x 1 columns]

# %%
x = [i for i in np.arange(1,137,1)]
y = clean_BTC['BTC-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('BTC Crypto')

plt.show()

# %%
tickers = ["XRP-USD"]
XRP_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = XRP_stock['Adj Close']
multpl_stock_monthly_returns2 = XRP_stock['Adj Close']

clean_XRP = multpl_stock_daily_returns2.dropna()
clean_XRP

x = [i for i in np.arange(1,137,1)]
y = clean_XRP['XRP-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('XRP crypto')

plt.show()

# %%
tickers = ["LTC-USD"]
LTC_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = LTC_stock['Adj Close']
multpl_stock_monthly_returns2 = LTC_stock['Adj Close']

clean_LTC = multpl_stock_daily_returns2.dropna()
clean_LTC

x = [i for i in np.arange(1,137,1)]
y = clean_LTC['LTC-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('LTC Crypto')

plt.show()

# %%
tickers = ["LTC-USD"]
LTC_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = LTC_stock['Adj Close']
multpl_stock_monthly_returns2 = LTC_stock['Adj Close']

clean_LTC = multpl_stock_daily_returns2.dropna()
clean_LTC

x = [i for i in np.arange(1,137,1)]
y = clean_LTC['LTC-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('LTC Crypto')

plt.show()
tickers = ["XRP-USD"]
XRP_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = XRP_stock['Adj Close']
multpl_stock_monthly_returns2 = XRP_stock['Adj Close']

clean_XRP = multpl_stock_daily_returns2.dropna()
clean_XRP

x = [i for i in np.arange(1,137,1)]
y = clean_XRP['XRP-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('XRP crypto')

plt.show()
