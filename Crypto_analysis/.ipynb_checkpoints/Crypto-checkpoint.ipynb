# 2021-01-06  1.074388e+10
# 2021-01-07  1.309958e+10
# 2021-01-08  1.470561e+10
# 2021-01-09  1.113678e+10
# 2021-01-10  1.277446e+10
# 2021-01-11  1.799426e+10
# 2021-01-12  1.189888e+10
# 2021-01-13  8.421749e+09
# 2021-01-14  8.271412e+09
# 2021-01-15  8.416625e+09
# 2021-01-16  7.183808e+09
# 2021-01-17  6.098836e+09
# 2021-01-18  6.640212e+09
# 2021-01-19  9.314780e+09
# 2021-01-20  9.002037e+09
# 2021-01-21  8.703006e+09
# 2021-01-22  8.550579e+09
#
# [22 rows x 36 columns]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)

ax1.plot(multpl_crypto['Adj Close']['BTC-USD'])
ax1.set_title("BTC-USD")
ax2.plot(multpl_crypto['Adj Close']['ETH-USD'])
ax2.set_title("ETH-USD")
ax3.plot(multpl_crypto['Adj Close']['DOT1-USD'])
ax3.set_title("DOT1-USD")
ax4.plot(multpl_crypto['Adj Close']['KSM-USD'])
ax4.set_title("KSM-USD")
ax5.plot(multpl_crypto['Adj Close']['ADA-USD'])
ax5.set_title("ADA-USD")
ax6.plot(multpl_crypto['Adj Close']['LTC-USD'])
ax6.set_title("LTC-USD")

plt.tight_layout()
plt.show()

# %%
multpl_stock_daily_returns = multpl_crypto['Adj Close'].pct_change()
multpl_stock_monthly_returns = multpl_crypto['Adj Close'].resample('M').ffill().pct_change()

# %%
fig = plt.figure()
(multpl_stock_daily_returns + 1).cumprod().plot(figsize=(10,5))
plt.show()

# %%
mean_df = pd.DataFrame(multpl_stock_daily_returns.mean())
mean_df
# Out:
#                  0
# Symbols
# BTC-USD   0.007384
# ETH-USD   0.029322
# DOT1-USD  0.040899
# KSM-USD   0.023755
# ADA-USD   0.038700
# LTC-USD   0.006983

# %%
mean_df.plot.barh()
plt.title('Average Return')
plt.xlabel('Return/month (x100)')
plt.legend('')

# %%
Std_df = pd.DataFrame(multpl_stock_daily_returns.std())
Std_df
# Out:
#                  0
# Symbols
# BTC-USD   0.061538
# ETH-USD   0.091132
# DOT1-USD  0.137532
# KSM-USD   0.098761
# ADA-USD   0.107484
# LTC-USD   0.078194

# %%
Std_df.plot.barh()
plt.title('Volatility')
plt.xlabel('Standard Deviation')
plt.legend('')

# %%
corr_df = (multpl_stock_daily_returns.corr())
corr_df
# Out:
# Symbols    BTC-USD   ETH-USD  DOT1-USD   KSM-USD   ADA-USD   LTC-USD
# Symbols
# BTC-USD   1.000000  0.664032  0.385867  0.521505  0.520686  0.784689
# ETH-USD   0.664032  1.000000  0.395051  0.513174  0.695913  0.885119
# DOT1-USD  0.385867  0.395051  1.000000  0.804181  0.342877  0.449356
# KSM-USD   0.521505  0.513174  0.804181  1.000000  0.571432  0.581460
# ADA-USD   0.520686  0.695913  0.342877  0.571432  1.000000  0.597142
# LTC-USD   0.784689  0.885119  0.449356  0.581460  0.597142  1.000000

# %%
corrMatrix = corr_df.corr()
sn.heatmap(corrMatrix, 
           annot=True,
           vmin=-1, vmax=1, center=0,
           cmap=sn.diverging_palette(20, 220, n=200),
           square=True
          )
plt.show()

# %%
tickers = ["ADA-USD", "ETH-USD", "DOT1-USD"]
multpl_stocks_top_3 = web.get_data_yahoo(tickers,
start = "2020-12-01",
end = "2021-01-21")

# %%
multpl_stock_daily_returns2 = multpl_stocks_top_3['Adj Close'].pct_change()
multpl_stock_monthly_returns2 = multpl_stocks_top_3['Adj Close'].resample('M').ffill().pct_change()

# %%
fig = plt.figure()
(multpl_stock_daily_returns2 + 1).cumprod().plot()

plt.show()

# %%
tickers = ["KSM-USD"]
DOT1_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = DOT1_stock['Adj Close']
multpl_stock_monthly_returns2 = DOT1_stock['Adj Close'].resample('M').ffill()

clean_DOT1 = multpl_stock_monthly_returns2.dropna()
print(clean_DOT1)
#multpl_stock_monthly_returns2
# Out:
# Symbols        KSM-USD
# Date
# 2020-08-31   41.382156
# 2020-09-30   34.050755
# 2020-10-31   30.436148
# 2020-11-30   52.118801
# 2020-12-31   71.959625
# 2021-01-31  109.287666

# %%
x = [i for i in np.arange(1,7,1)]
y = clean_DOT1['KSM-USD']

fig = plt.scatter(x, y)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.show()

# %%
multpl_stock_daily_returns2 = DOT1_stock['Adj Close']
multpl_stock_monthly_returns2 = DOT1_stock['Adj Close'].resample('M').ffill()

DOT1_stock2 = multpl_stock_daily_returns2.dropna()
DOT1_stock2
# Out:
# Symbols        KSM-USD
# Date
# 2020-08-31   41.382156
# 2020-09-01   57.690388
# 2020-09-02   44.930496
# 2020-09-03   42.449684
# 2020-09-25   35.929001
# ...                ...
# 2021-01-14   88.013840
# 2021-01-15   83.522697
# 2021-01-16  103.246452
# 2021-01-17  102.568123
# 2021-01-18  109.287666
#
# [102 rows x 1 columns]

# %%
x = [i for i in np.arange(1,103,1)]
y = DOT1_stock2['KSM-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('KSM Crypto')

plt.show()

# %%
tickers = ["ETH-USD"]
ETH_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = ETH_stock['Adj Close']
multpl_stock_monthly_returns2 = ETH_stock['Adj Close'].resample('M').ffill()

clean_ETH = multpl_stock_daily_returns2.dropna()
clean_ETH
# Out:
# Symbols         ETH-USD
# Date
# 2020-08-31   477.051910
# 2020-09-01   440.040497
# 2020-09-02   385.671936
# 2020-09-03   388.241150
# 2020-09-04   335.260071
# ...                 ...
# 2021-01-14  1218.453003
# 2021-01-15  1171.834595
# 2021-01-16  1233.537598
# 2021-01-17  1230.172241
# 2021-01-18  1257.279541
#
# [137 rows x 1 columns]

# %%
x = [i for i in np.arange(1,138,1)]
y = clean_ETH['ETH-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('ETH Crypto')

plt.show()

# %%
tickers = ["ADA-USD"]
ADA_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = ADA_stock['Adj Close']
multpl_stock_monthly_returns2 = ADA_stock['Adj Close']

clean_ADA = multpl_stock_daily_returns2.dropna()
clean_ADA
# Out:
# Symbols      ADA-USD
# Date
# 2020-08-31  0.125411
# 2020-09-01  0.115613
# 2020-09-02  0.096154
# 2020-09-03  0.102445
# 2020-09-04  0.089923
# ...              ...
# 2021-01-14  0.310396
# 2021-01-15  0.302530
# 2021-01-16  0.352444
# 2021-01-17  0.379852
# 2021-01-18  0.371428
#
# [137 rows x 1 columns]

# %%
x = [i for i in np.arange(1,138,1)]
y = clean_ADA['ADA-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Crypto Price')
plt.title('ADA Crypto')

plt.show()

# %%
tickers = ["BTC-USD"]
BTC_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

# %%
multpl_stock_daily_returns2 = BTC_stock['Adj Close']
multpl_stock_monthly_returns2 = BTC_stock['Adj Close']

clean_BTC = multpl_stock_daily_returns2.dropna()
clean_BTC
# Out:
# Symbols          BTC-USD
# Date
# 2020-08-31  11970.478516
# 2020-09-01  11414.034180
# 2020-09-02  10245.296875
# 2020-09-03  10511.813477
# 2020-09-04  10169.567383
# ...                  ...
# 2021-01-14  39187.328125
# 2021-01-15  36825.367188
# 2021-01-16  36178.140625
# 2021-01-17  35791.277344
# 2021-01-18  36630.074219
#
# [137 rows x 1 columns]

# %%
x = [i for i in np.arange(1,138,1)]
y = clean_BTC['BTC-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('BTC Crypto')

plt.show()

# %%
tickers = ["XRP-USD"]
XRP_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = XRP_stock['Adj Close']
multpl_stock_monthly_returns2 = XRP_stock['Adj Close']

clean_XRP = multpl_stock_daily_returns2.dropna()
clean_XRP

x = [i for i in np.arange(1,138,1)]
y = clean_XRP['XRP-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('XRP crypto')

plt.show()

# %%
tickers = ["LTC-USD"]
LTC_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = LTC_stock['Adj Close']
multpl_stock_monthly_returns2 = LTC_stock['Adj Close']

clean_LTC = multpl_stock_daily_returns2.dropna()
clean_LTC

x = [i for i in np.arange(1,138,1)]
y = clean_LTC['LTC-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('LTC Crypto')

plt.show()

# %%
tickers = ["LTC-USD"]
LTC_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = LTC_stock['Adj Close']
multpl_stock_monthly_returns2 = LTC_stock['Adj Close']

clean_LTC = multpl_stock_daily_returns2.dropna()
clean_LTC

x = [i for i in np.arange(1,138,1)]
y = clean_LTC['LTC-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('LTC Crypto')

plt.show()
tickers = ["XRP-USD"]
XRP_stock = web.get_data_yahoo(tickers,
start = "2020-09-01",
end = "2021-01-17")

multpl_stock_daily_returns2 = XRP_stock['Adj Close']
multpl_stock_monthly_returns2 = XRP_stock['Adj Close']

clean_XRP = multpl_stock_daily_returns2.dropna()
clean_XRP

x = [i for i in np.arange(1,138,1)]
y = clean_XRP['XRP-USD']

fig = plt.scatter(x, y, c='darkblue', s=5)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.xlabel('Time period - Days')
plt.ylabel('Stock Price')
plt.title('XRP crypto')

plt.show()

# %%
BTC_df = web.get_data_yahoo("BTC-USD",
start = "2020-11-01",
end = "2021-01-17")

BTC_df
# Out:
#                     High           Low          Open         Close  \
# Date
# 2020-11-01  13862.033203  13628.377930  13780.995117  13737.109375
# 2020-11-02  13808.323242  13243.160156  13737.032227  13550.489258
# 2020-11-03  13984.981445  13325.441406  13550.451172  13950.300781
# 2020-11-04  14218.766602  13580.471680  13950.488281  14133.707031
# 2020-11-05  15706.404297  14102.088867  14133.733398  15579.848633
# ...                  ...           ...           ...           ...
# 2021-01-14  39966.406250  36868.562500  37325.109375  39187.328125
# 2021-01-15  39577.710938  34659.589844  39156.707031  36825.367188
# 2021-01-16  37864.367188  35633.554688  36821.648438  36178.140625
# 2021-01-17  36722.351562  34069.320312  36163.648438  35791.277344
# 2021-01-18  37299.285156  34883.843750  35792.238281  36630.074219
#
#                  Volume     Adj Close
# Date
# 2020-11-01  24453857900  13737.109375
# 2020-11-02  30771455468  13550.489258
# 2020-11-03  29869951617  13950.300781
# 2020-11-04  35116364962  14133.707031
# 2020-11-05  40856321439  15579.848633
# ...                 ...           ...
# 2021-01-14  63615990033  39187.328125
# 2021-01-15  67760757881  36825.367188
# 2021-01-16  57706187875  36178.140625
# 2021-01-17  52359854336  35791.277344
# 2021-01-18  49511702429  36630.074219
#
# [79 rows x 6 columns]

# %%
mpf.plot(BTC_df, type='candle', style='charles',
        title='BITCOIN',
        ylabel='Price ($)',
        ylabel_lower='Trade \nVolume',
        volume=True, 
        mav=(3,9,16)
        )

plt.show()
